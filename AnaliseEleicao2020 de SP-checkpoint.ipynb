# %%
#Nome: Matheus Ribeiro dos Santos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:\Users\Matheus Ribeiro\votacao_candidato_munzona_2020_SP.csv'
df = pd.read_csv(filename,encoding='latin-1',sep = ';',error_bad_lines=False)

# %%
df.shape
# Out:
# (224308, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224308 entries, 0 to 224307
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_GERACAO                224308 non-null  object
#  1   HH_GERACAO                224308 non-null  object
#  2   ANO_ELEICAO               224308 non-null  int64
#  3   CD_TIPO_ELEICAO           224308 non-null  int64
#  4   NM_TIPO_ELEICAO           224308 non-null  object
#  5   NR_TURNO                  224308 non-null  int64
#  6   CD_ELEICAO                224308 non-null  int64
#  7   DS_ELEICAO                224308 non-null  object
#  8   DT_ELEICAO                224308 non-null  object
#  9   TP_ABRANGENCIA            224308 non-null  object
#  10  SG_UF                     224308 non-null  object
#  11  SG_UE                     224308 non-null  int64
#  12  NM_UE                     224308 non-null  object
# ...

# %%
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 84723   28/11/2020   07:17:07         2020                2
# 15521   28/11/2020   07:17:07         2020                2
# 104570  28/11/2020   07:17:07         2020                2
# 208781  28/11/2020   07:17:07         2020                2
# 75058   28/11/2020   07:17:07         2020                2
# 146216  28/11/2020   07:17:07         2020                2
# 40184   28/11/2020   07:17:07         2020                2
# 83805   28/11/2020   07:17:07         2020                2
# 209043  28/11/2020   07:17:07         2020                2
# 168491  28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 84723   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 15521   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 104570  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# ...

# %%
df['CD_CARGO'].value_counts()
# Out:
# 13    220607
# 11      3701
# Name: CD_CARGO, dtype: int64

# %%
df[(df['CD_CARGO']==11)].iloc[0:1,10:19]
# Out:
#   SG_UF  SG_UE            NM_UE  CD_MUNICIPIO     NM_MUNICIPIO  NR_ZONA  \
# 6    SP  71579  TABOÃO DA SERRA         71579  TABOÃO DA SERRA      324
#
#    CD_CARGO  DS_CARGO  SQ_CANDIDATO
# 6        11  Prefeito  250000678328

# %%
vereador = df[(df['CD_CARGO']==13)|(df['CD_CARGO']==13)]

# %%
vereador.sample(5)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 50511   28/11/2020   07:17:07         2020                2
# 32844   28/11/2020   07:17:07         2020                2
# 37759   28/11/2020   07:17:07         2020                2
# 114367  28/11/2020   07:17:07         2020                2
# 55606   28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 50511   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 32844   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 37759   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 114367  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 55606   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
#
#         DT_ELEICAO TP_ABRANGENCIA SG_UF  SG_UE      NM_UE  CD_MUNICIPIO  \
# 50511   15/11/2020              M    SP  71072  SÃO PAULO         71072
# ...

# %%
#Partido com mais vereadores no Estado de São Paulo

# %%
vereador.groupby('SG_PARTIDO').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='SG_PARTIDO'>

# %%
#vereador com mais voto no estado de SP

# %%
vereador.groupby('NM_CANDIDATO')['QT_VOTOS_NOMINAIS'].max().sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NM_CANDIDATO'>

# %%
vereador['DS_SIT_TOT_TURNO'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
prefeito = df[(df['CD_CARGO']==11)]

# %%
prefeito.sample(5)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 28111   28/11/2020   07:17:07         2020                2
# 98708   28/11/2020   07:17:07         2020                2
# 41233   28/11/2020   07:17:07         2020                2
# 15013   28/11/2020   07:17:07         2020                2
# 157638  28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 28111   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 98708   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 41233   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 15013   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 157638  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
#
#         DT_ELEICAO TP_ABRANGENCIA SG_UF  SG_UE       NM_UE  CD_MUNICIPIO  \
# 28111   15/11/2020              M    SP  61611      ARANDU         61611
# ...

# %%
#prefeito com mais voto no estado de SP

# %%
prefeito.groupby('NM_CANDIDATO')['QT_VOTOS_NOMINAIS'].max().sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NM_CANDIDATO'>

# %%
prefeito['DS_SIT_TOT_TURNO'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>
