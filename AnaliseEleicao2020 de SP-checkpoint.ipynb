# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:\Users\Matheus Ribeiro\votacao_candidato_munzona_2020_SP.csv'
df = pd.read_csv(filename,encoding='latin-1',sep = ';',error_bad_lines=False)

# %%
df.shape
# Out:
# (224308, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224308 entries, 0 to 224307
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_GERACAO                224308 non-null  object
#  1   HH_GERACAO                224308 non-null  object
#  2   ANO_ELEICAO               224308 non-null  int64
#  3   CD_TIPO_ELEICAO           224308 non-null  int64
#  4   NM_TIPO_ELEICAO           224308 non-null  object
#  5   NR_TURNO                  224308 non-null  int64
#  6   CD_ELEICAO                224308 non-null  int64
#  7   DS_ELEICAO                224308 non-null  object
#  8   DT_ELEICAO                224308 non-null  object
#  9   TP_ABRANGENCIA            224308 non-null  object
#  10  SG_UF                     224308 non-null  object
#  11  SG_UE                     224308 non-null  int64
#  12  NM_UE                     224308 non-null  object
#  13  CD_MUNICIPIO              224308 non-null  int64
#  14  NM_MUNICIPIO              224308 non-null  object
#  15  NR_ZONA                   224308 non-null  int64
#  16  CD_CARGO                  224308 non-null  int64
#  17  DS_CARGO                  224308 non-null  object
#  18  SQ_CANDIDATO              224308 non-null  int64
#  19  NR_CANDIDATO              224308 non-null  int64
#  20  NM_CANDIDATO              224308 non-null  object
#  21  NM_URNA_CANDIDATO         224307 non-null  object
#  22  NM_SOCIAL_CANDIDATO       224308 non-null  object
#  23  CD_SITUACAO_CANDIDATURA   224308 non-null  int64
#  24  DS_SITUACAO_CANDIDATURA   224308 non-null  object
#  25  CD_DETALHE_SITUACAO_CAND  224308 non-null  int64
#  26  DS_DETALHE_SITUACAO_CAND  224308 non-null  object
#  27  TP_AGREMIACAO             224308 non-null  object
#  28  NR_PARTIDO                224308 non-null  int64
#  29  SG_PARTIDO                224308 non-null  object
#  30  NM_PARTIDO                224308 non-null  object
#  31  SQ_COLIGACAO              224308 non-null  int64
#  32  NM_COLIGACAO              224308 non-null  object
#  33  DS_COMPOSICAO_COLIGACAO   224308 non-null  object
#  34  CD_SIT_TOT_TURNO          224308 non-null  int64
#  35  DS_SIT_TOT_TURNO          224308 non-null  object
#  36  ST_VOTO_EM_TRANSITO       224308 non-null  object
#  37  QT_VOTOS_NOMINAIS         224308 non-null  int64
# dtypes: int64(16), object(22)
# memory usage: 65.0+ MB

# %%
df.sample(10)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 179868  28/11/2020   07:17:07         2020                2
# 103211  28/11/2020   07:17:07         2020                2
# 186467  28/11/2020   07:17:07         2020                2
# 46628   28/11/2020   07:17:07         2020                2
# 144301  28/11/2020   07:17:07         2020                2
# 68844   28/11/2020   07:17:07         2020                2
# 185675  28/11/2020   07:17:07         2020                2
# 190145  28/11/2020   07:17:07         2020                2
# 58016   28/11/2020   07:17:07         2020                2
# 138953  28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 179868  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 103211  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 186467  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 46628   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 144301  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 68844   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 185675  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 190145  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 58016   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 138953  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
#
#         DT_ELEICAO TP_ABRANGENCIA SG_UF  SG_UE                NM_UE  \
# 179868  15/11/2020              M    SP  71072            SÃO PAULO
# 103211  15/11/2020              M    SP  71072            SÃO PAULO
# 186467  15/11/2020              M    SP  71838              TAUBATÉ
# 46628   15/11/2020              M    SP  61514    APARECIDA D OESTE
# 144301  15/11/2020              M    SP  71498               SUMARÉ
# 68844   15/11/2020              M    SP  70572          SANTO ANDRÉ
# 185675  15/11/2020              M    SP  71072            SÃO PAULO
# 190145  15/11/2020              M    SP  69833  RIO GRANDE DA SERRA
# 58016   15/11/2020              M    SP  72435           VOTORANTIM
# 138953  15/11/2020              M    SP  71072            SÃO PAULO
#
#         CD_MUNICIPIO         NM_MUNICIPIO  NR_ZONA  CD_CARGO  DS_CARGO  \
# 179868         71072            SÃO PAULO      398        13  Vereador
# 103211         71072            SÃO PAULO      280        13  Vereador
# 186467         71838              TAUBATÉ      141        13  Vereador
# 46628          61514    APARECIDA D OESTE      232        13  Vereador
# 144301         71498               SUMARÉ      362        13  Vereador
# 68844          70572          SANTO ANDRÉ      306        13  Vereador
# 185675         71072            SÃO PAULO      405        13  Vereador
# 190145         69833  RIO GRANDE DA SERRA      382        13  Vereador
# 58016          72435           VOTORANTIM      220        13  Vereador
# 138953         71072            SÃO PAULO      247        13  Vereador
#
#         SQ_CANDIDATO  NR_CANDIDATO                           NM_CANDIDATO  \
# 179868  250000789510         13025                ALLAN LOURENÇO DE BRITO
# 103211  250000925981         20038                     MARISTELA TRINDADE
# 186467  250001174812         36777               CLÁUDIO MARTINS DE BRITO
# 46628   250000810326         55123                  GILBERTO JOSÉ BELLOTO
# 144301  250001183275         17555                         CLAUDETE PONGA
# 68844   250001181188         70700            SIMONE APARECIDA DE RESENDE
# 185675  250001123225         40040           SAMUEL EMILIO SANTOS DE MELO
# 190145  250001033437         15015  MICHEL CLEITON ALVES DOS SANTOS ROCHA
# 58016   250001214908         14500           LAURENTINA DE SOUZA VANZELLA
# 138953  250000883902         10124               SOLANGE DOS SANTOS SILVA
#
#            NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  CD_SITUACAO_CANDIDATURA  \
# 179868           ALLAN BRITO              #NULO#                       12
# 103211    MARISTELA TRINDADE              #NULO#                       12
# 186467     CLÁUDIO DO ABRIGO              #NULO#                       12
# 46628     PROFESSOR GILBERTO              #NULO#                       12
# 144301  CLAUDETE DO POSTINHO              #NULO#                       12
# 68844     DRA SIMONE RESENDE              #NULO#                       12
# 185675         SAMUEL EMÍLIO              #NULO#                       12
# 190145         MICHEL KADOSH              #NULO#                       12
# 58016     LAURA CABELEIREIRA              #NULO#                       12
# 138953         SOLANGE PAULA              #NULO#                       12
#
#        DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 179868                    APTO                         2
# 103211                    APTO                         2
# 186467                    APTO                         2
# 46628                     APTO                         2
# 144301                    APTO                         2
# 68844                     APTO                         2
# 185675                    APTO                         2
# 190145                    APTO                         2
# 58016                     APTO                         2
# 138953                    APTO                         2
#
#        DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO    SG_PARTIDO  \
# 179868                 DEFERIDO  Partido isolado          13            PT
# 103211                 DEFERIDO  Partido isolado          20           PSC
# 186467                 DEFERIDO  Partido isolado          36           PTC
# 46628                  DEFERIDO  Partido isolado          55           PSD
# 144301                 DEFERIDO  Partido isolado          17           PSL
# 68844                  DEFERIDO  Partido isolado          70        AVANTE
# 185675                 DEFERIDO  Partido isolado          40           PSB
# 190145                 DEFERIDO  Partido isolado          15           MDB
# 58016                  DEFERIDO  Partido isolado          14           PTB
# 138953                 DEFERIDO  Partido isolado          10  REPUBLICANOS
#
#                               NM_PARTIDO  SQ_COLIGACAO     NM_COLIGACAO  \
# 179868         Partido dos Trabalhadores  250000077014  PARTIDO ISOLADO
# 103211            Partido Social Cristão  250000106600  PARTIDO ISOLADO
# 186467       Partido Trabalhista Cristão  250000144656  PARTIDO ISOLADO
# 46628         Partido Social Democrático  250000081169  PARTIDO ISOLADO
# 144301            Partido Social Liberal  250000145611  PARTIDO ISOLADO
# 68844                             AVANTE  250000145401  PARTIDO ISOLADO
# 185675     Partido Socialista Brasileiro  250000136167  PARTIDO ISOLADO
# 190145  Movimento Democrático Brasileiro  250000124509  PARTIDO ISOLADO
# 58016     Partido Trabalhista Brasileiro  250000149587  PARTIDO ISOLADO
# 138953                      REPUBLICANOS  250000098697  PARTIDO ISOLADO
#
#        DS_COMPOSICAO_COLIGACAO  CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  \
# 179868                      PT                 5         SUPLENTE
# 103211                     PSC                 5         SUPLENTE
# 186467                     PTC                 4       NÃO ELEITO
# 46628                      PSD                 5         SUPLENTE
# 144301                     PSL                 4       NÃO ELEITO
# 68844                   AVANTE                 5         SUPLENTE
# 185675                     PSB                 5         SUPLENTE
# 190145                     MDB                 4       NÃO ELEITO
# 58016                      PTB                 5         SUPLENTE
# 138953            REPUBLICANOS                 5         SUPLENTE
#
#        ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS
# 179868                   N                  3
# 103211                   N                 14
# 186467                   N                 14
# 46628                    N                106
# 144301                   N                  4
# 68844                    N                 34
# 185675                   N                 27
# 190145                   N                113
# 58016                    N                 71
# 138953                   N                  1

# %%
df['CD_CARGO'].value_counts()
# Out:
# 13    220607
# 11      3701
# Name: CD_CARGO, dtype: int64

# %%
df[(df['CD_CARGO']==11)].iloc[0:1,10:19]
# Out:
#   SG_UF  SG_UE            NM_UE  CD_MUNICIPIO     NM_MUNICIPIO  NR_ZONA  \
# 6    SP  71579  TABOÃO DA SERRA         71579  TABOÃO DA SERRA      324
#
#    CD_CARGO  DS_CARGO  SQ_CANDIDATO
# 6        11  Prefeito  250000678328

# %%
vereador = df[(df['CD_CARGO']==13)|(df['CD_CARGO']==13)]

# %%
vereador.sample(5)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 148353  28/11/2020   07:17:07         2020                2
# 221820  28/11/2020   07:17:07         2020                2
# 30397   28/11/2020   07:17:07         2020                2
# 218349  28/11/2020   07:17:07         2020                2
# 13530   28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 148353  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 221820  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 30397   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 218349  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 13530   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
#
#         DT_ELEICAO TP_ABRANGENCIA SG_UF  SG_UE      NM_UE  CD_MUNICIPIO  \
# 148353  15/11/2020              M    SP  71072  SÃO PAULO         71072
# 221820  15/11/2020              M    SP  71072  SÃO PAULO         71072
# 30397   15/11/2020              M    SP  71072  SÃO PAULO         71072
# 218349  15/11/2020              M    SP  71072  SÃO PAULO         71072
# 13530   15/11/2020              M    SP  71072  SÃO PAULO         71072
#
#        NM_MUNICIPIO  NR_ZONA  CD_CARGO  DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 148353    SÃO PAULO      376        13  Vereador  250001123241         40193
# 221820    SÃO PAULO      254        13  Vereador  250001016153         55125
# 30397     SÃO PAULO      250        13  Vereador  250001088458         15515
# 218349    SÃO PAULO      347        13  Vereador  250001041961         28202
# 13530     SÃO PAULO      320        13  Vereador  250001100742         35789
#
#                                 NM_CANDIDATO    NM_URNA_CANDIDATO  \
# 148353        FRANCISCO CARLOS LAROCA JUNIOR       CAPITÃO LAROCA
# 221820          FRANCISCO JOSÉ DA CRUZ FILHO       FRANCISCO JOSÉ
# 30397       CINTIA COUTINHO BELTRAME MARIANO      CINTIA BELTRAME
# 218349                   CARLOS ARAUJO SOUTO         CARLOS SOUTO
# 13530   PAULO CESAR SOARES DE ALMEIDA SANTOS  PASTOR PAULO SOARES
#
#        NM_SOCIAL_CANDIDATO  CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  \
# 148353              #NULO#                       12                    APTO
# 221820              #NULO#                       12                    APTO
# 30397               #NULO#                       12                    APTO
# 218349              #NULO#                       12                    APTO
# 13530               #NULO#                       12                    APTO
#
#         CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 148353                         2                 DEFERIDO  Partido isolado
# 221820                         2                 DEFERIDO  Partido isolado
# 30397                          2                 DEFERIDO  Partido isolado
# 218349                         2                 DEFERIDO  Partido isolado
# 13530                          2                 DEFERIDO  Partido isolado
#
#         NR_PARTIDO SG_PARTIDO                                NM_PARTIDO  \
# 148353          40        PSB             Partido Socialista Brasileiro
# 221820          55        PSD                Partido Social Democrático
# 30397           15        MDB          Movimento Democrático Brasileiro
# 218349          28       PRTB  Partido Renovador Trabalhista Brasileiro
# 13530           35        PMB              Partido da Mulher Brasileira
#
#         SQ_COLIGACAO     NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  \
# 148353  250000136167  PARTIDO ISOLADO                     PSB
# 221820  250000120047  PARTIDO ISOLADO                     PSD
# 30397   250000131804  PARTIDO ISOLADO                     MDB
# 218349  250000125795  PARTIDO ISOLADO                    PRTB
# 13530   250000133375  PARTIDO ISOLADO                     PMB
#
#         CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_VOTO_EM_TRANSITO  \
# 148353                 5         SUPLENTE                   N
# 221820                 5         SUPLENTE                   N
# 30397                  5         SUPLENTE                   N
# 218349                 4       NÃO ELEITO                   N
# 13530                  4       NÃO ELEITO                   N
#
#         QT_VOTOS_NOMINAIS
# 148353                 39
# 221820                  0
# 30397                   2
# 218349                  1
# 13530                   3

# %%
#Partido com mais vereadores no Estado de São Paulo

# %%
vereador.groupby('SG_PARTIDO').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='SG_PARTIDO'>

# %%
#vereador com mais voto no estado de SP

# %%
vereador.groupby('NM_CANDIDATO')['QT_VOTOS_NOMINAIS'].max().sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NM_CANDIDATO'>

# %%
vereador['DS_SIT_TOT_TURNO'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
prefeito = df[(df['CD_CARGO']==11)]

# %%
prefeito.sample(5)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 170357  28/11/2020   07:17:07         2020                2
# 179945  28/11/2020   07:17:07         2020                2
# 192933  28/11/2020   07:17:07         2020                2
# 83185   28/11/2020   07:17:07         2020                2
# 16267   28/11/2020   07:17:07         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 170357  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 179945  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 192933  Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 83185   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
# 16267   Eleição Ordinária         1         426  ELEIÇÕES MUNICIPAIS 2020
#
#         DT_ELEICAO TP_ABRANGENCIA SG_UF  SG_UE                  NM_UE  \
# 170357  15/11/2020              M    SP  70750  SÃO BERNARDO DO CAMPO
# 179945  15/11/2020              M    SP  66893                   MAUÁ
# 192933  15/11/2020              M    SP  61565                  POTIM
# 83185   15/11/2020              M    SP  62910               CAMPINAS
# 16267   15/11/2020              M    SP  63673               CRUZÁLIA
#
#         CD_MUNICIPIO           NM_MUNICIPIO  NR_ZONA  CD_CARGO  DS_CARGO  \
# 170357         70750  SÃO BERNARDO DO CAMPO      296        11  Prefeito
# 179945         66893                   MAUÁ      217        11  Prefeito
# 192933         61565                  POTIM      190        11  Prefeito
# 83185          62910               CAMPINAS      275        11  Prefeito
# 16267          63673               CRUZÁLIA      290        11  Prefeito
#
#         SQ_CANDIDATO  NR_CANDIDATO               NM_CANDIDATO  \
# 170357  250000811317            16  CLAUDIO DONIZETE DOS REIS
# 179945  250000660280            11       RONALDO LUIZ PEDROSA
# 192933  250000931667            17    BENEDICTO CARLOS THOMAZ
# 83185   250000842845            16       LAURA LEAL DE CASTRO
# 16267   250001225700            45       ARILDO OSMAR DE MORO
#
#        NM_URNA_CANDIDATO NM_SOCIAL_CANDIDATO  CD_SITUACAO_CANDIDATURA  \
# 170357  CLAUDIO DONIZETE              #NULO#                       12
# 179945   RONALDO PEDROSA              #NULO#                       12
# 192933     CARLINHO ZAGA              #NULO#                       12
# 83185         LAURA LEAL              #NULO#                       12
# 16267    ARILDO MOSQUITO              #NULO#                       12
#
#        DS_SITUACAO_CANDIDATURA  CD_DETALHE_SITUACAO_CAND  \
# 170357                    APTO                         2
# 179945                    APTO                         2
# 192933                    APTO                         2
# 83185                     APTO                         2
# 16267                     APTO                         2
#
#        DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO SG_PARTIDO  \
# 170357                 DEFERIDO  Partido isolado          16       PSTU
# 179945                 DEFERIDO  Partido isolado          11         PP
# 192933                 DEFERIDO  Partido isolado          17        PSL
# 83185                  DEFERIDO  Partido isolado          16       PSTU
# 16267                  DEFERIDO        Coligação          45       PSDB
#
#                                             NM_PARTIDO  SQ_COLIGACAO  \
# 170357  Partido Socialista dos Trabalhadores Unificado  250000081375
# 179945                                   PROGRESSISTAS  250000058918
# 192933                          Partido Social Liberal  250000107373
# 83185   Partido Socialista dos Trabalhadores Unificado  250000090062
# 16267          Partido da Social Democracia Brasileira  250000151242
#
#                                        NM_COLIGACAO DS_COMPOSICAO_COLIGACAO  \
# 170357                              PARTIDO ISOLADO                    PSTU
# 179945                              PARTIDO ISOLADO                      PP
# 192933                              PARTIDO ISOLADO                     PSL
# 83185                               PARTIDO ISOLADO                    PSTU
# 16267   JUVENTUDE E EXPERIENCIA UNIDAS POR CRUZALIA              DEM / PSDB
#
#         CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO ST_VOTO_EM_TRANSITO  \
# 170357                 4       NÃO ELEITO                   N
# 179945                 4       NÃO ELEITO                   N
# 192933                 4       NÃO ELEITO                   N
# 83185                  4       NÃO ELEITO                   N
# 16267                  1           ELEITO                   N
#
#         QT_VOTOS_NOMINAIS
# 170357                 90
# 179945                897
# 192933                163
# 83185                 114
# 16267                1056

# %%
#prefeito com mais voto no estado de SP

# %%
prefeito.groupby('NM_CANDIDATO')['QT_VOTOS_NOMINAIS'].max().sort_values().tail(5).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='NM_CANDIDATO'>

# %%
prefeito['DS_SIT_TOT_TURNO'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>
